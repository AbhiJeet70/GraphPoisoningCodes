# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhiJeet70/GraphPoisoningCodes/blob/main/Poison_Planetoid_numbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary packages
# !pip install torch torch_geometric pandas matplotlib

import torch
import torch.nn.functional as F
from torch_geometric.datasets import Planetoid
from torch_geometric.transforms import NormalizeFeatures
from torch_geometric.nn import GCNConv
import numpy as np
import random
import matplotlib.pyplot as plt
import pandas as pd

# Set random seed for reproducibility
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

set_seed(20)

# Define function to load Planetoid data for a given dataset name
def load_planetoid_data(dataset_name):
    dataset = Planetoid(root=f'/tmp/{dataset_name}', name=dataset_name, transform=NormalizeFeatures())
    data = dataset[0]
    return data

# Split data into train, validation, and test sets (if needed)
def split_indices(num_nodes, train_ratio=0.7, val_ratio=0.1):
    indices = np.random.permutation(num_nodes)
    train_end = int(train_ratio * num_nodes)
    val_end = int((train_ratio + val_ratio) * num_nodes)
    train_idx = torch.tensor(indices[:train_end], dtype=torch.long)
    val_idx = torch.tensor(indices[train_end:val_end], dtype=torch.long)
    test_idx = torch.tensor(indices[val_end:], dtype=torch.long)
    return train_idx, val_idx, test_idx

# Define the GCN model with 2 layers
class GCNNet(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels):
        super(GCNNet, self).__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, out_channels)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.conv2(x, edge_index)
        return F.log_softmax(x, dim=1)

# Train and evaluate the model
def train_model(model, pyg_data, lr, weight_decay):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    pyg_data = pyg_data.to(device)
    model = model.to(device)
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    best_val_acc = 0
    patience = 100
    patience_counter = 0

    for epoch in range(1, 501):
        model.train()
        optimizer.zero_grad()
        out = model(pyg_data.x, pyg_data.edge_index)
        loss = F.cross_entropy(out[pyg_data.train_mask], pyg_data.y[pyg_data.train_mask])
        loss.backward()
        optimizer.step()

        model.eval()
        _, pred = model(pyg_data.x, pyg_data.edge_index).max(dim=1)
        val_correct = float(pred[pyg_data.val_mask].eq(pyg_data.y[pyg_data.val_mask]).sum().item())
        val_acc = val_correct / pyg_data.val_mask.sum().item()

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            patience_counter = 0
            best_model_state = model.state_dict()
        else:
            patience_counter += 1

        if patience_counter >= patience:
            print(f'Early stopping at epoch {epoch}')
            break

    model.load_state_dict(best_model_state)
    model.eval()
    _, pred = model(pyg_data.x, pyg_data.edge_index).max(dim=1)
    correct = float(pred[pyg_data.test_mask].eq(pyg_data.y[pyg_data.test_mask]).sum().item())
    acc = correct / pyg_data.test_mask.sum().item()
    return acc

# Print dataset statistics
def print_dataset_statistics(data, dataset_name):
    num_nodes = data.num_nodes
    num_edges = data.num_edges
    num_features = data.num_node_features
    num_classes = data.y.max().item() + 1
    class_distribution = torch.bincount(data.y).cpu().numpy()
    print(f"Statistics for {dataset_name}:")
    print(f"  Number of nodes: {num_nodes}")
    print(f"  Number of edges: {num_edges}")
    print(f"  Number of features: {num_features}")
    print(f"  Number of classes: {num_classes}")
    print(f"  Class distribution: {class_distribution}")

def evenly_perturb_edges(data, perturbation_percentage):
    device = data.edge_index.device
    edge_index = data.edge_index.clone().to(device)
    num_edges = edge_index.size(1)
    num_nodes = data.num_nodes
    num_perturbations = int(num_edges * perturbation_percentage)

    perturbations_per_node = num_perturbations // num_nodes
    remaining_perturbations = num_perturbations

    for node in range(num_nodes):
        if remaining_perturbations <= 0:
            break

        connected_edges = (edge_index[0] == node) | (edge_index[1] == node)
        perturb_edges_idx = torch.nonzero(connected_edges, as_tuple=False).view(-1)

        if perturb_edges_idx.size(0) > 0:
            num_perturb_node_edges = min(perturbations_per_node, perturb_edges_idx.size(0))
            selected_edges_idx = perturb_edges_idx[torch.randperm(perturb_edges_idx.size(0))[:num_perturb_node_edges]]
            edge_index[:, selected_edges_idx] = torch.randint(0, num_nodes, edge_index[:, selected_edges_idx].shape, dtype=torch.long, device=device)
            remaining_perturbations -= num_perturb_node_edges

    data.edge_index = edge_index
    return data

def concentrated_perturb_edges(data, perturbation_percentage):
    device = data.edge_index.device
    edge_index = data.edge_index.clone().to(device)
    num_edges = edge_index.size(1)
    num_nodes = data.num_nodes
    num_perturbations = int(num_edges * perturbation_percentage)

    # Compute node degrees
    degrees = torch.zeros(num_nodes, dtype=torch.long, device=device)
    degrees.scatter_add_(0, edge_index[0], torch.ones(edge_index.size(1), dtype=torch.long, device=device))

    # Sort nodes by degree in descending order
    sorted_nodes = torch.argsort(degrees, descending=True)
    total_perturbations = 0
    nodes_used = 0

    for node in sorted_nodes:
        if total_perturbations >= num_perturbations:
            break

        connected_edges = (edge_index[0] == node) | (edge_index[1] == node)
        perturb_edges_idx = torch.nonzero(connected_edges, as_tuple=False).view(-1)

        if perturb_edges_idx.size(0) > 0:
            num_node_edges = perturb_edges_idx.size(0)
            edge_index[:, perturb_edges_idx] = torch.randint(0, num_nodes, edge_index[:, perturb_edges_idx].shape, dtype=torch.long, device=device)
            total_perturbations += num_node_edges
            nodes_used += 1

    data.edge_index = edge_index
    print(f"Number of nodes used for perturbation: {nodes_used}")
    return data, nodes_used

# Hyperparameter grid search
hidden_channels_list = [16, 32, 64, 128, 256, 512]  # Reduced for quicker testing
learning_rates = [0.1, 0.01, 0.001]    # Reduced for quicker testing
weight_decays = [1e-4, 1e-5]

# List of datasets to process
datasets = ['Cora', 'Pubmed', 'CiteSeer']

# Initialize results DataFrame
results_df = pd.DataFrame(columns=['Dataset', 'Hidden_Channels', 'Learning_Rate', 'Weight_Decay', 'Accuracy', 'Perturbation_Type', 'Perturbation_Percentage'])

# Process each dataset and print accuracies
for dataset_name in datasets:
    print(f'Processing dataset: {dataset_name}')
    data = load_planetoid_data(dataset_name)
    print_dataset_statistics(data, dataset_name)

    train_idx, val_idx, test_idx = split_indices(data.num_nodes)
    data.train_mask = torch.zeros(data.num_nodes, dtype=torch.bool)
    data.val_mask = torch.zeros(data.num_nodes, dtype=torch.bool)
    data.test_mask = torch.zeros(data.num_nodes, dtype=torch.bool)
    data.train_mask[train_idx] = True
    data.val_mask[val_idx] = True
    data.test_mask[test_idx] = True

    # Determine number of classes from labels
    num_classes = data.y.max().item() + 1

    # Hyperparameter tuning
    best_accuracy = 0
    best_hyperparams = {}
    for hidden_channels in hidden_channels_list:
        for lr in learning_rates:
            for weight_decay in weight_decays:
                model = GCNNet(data.num_node_features, hidden_channels, num_classes)
                accuracy = train_model(model, data, lr, weight_decay)
                if accuracy > best_accuracy:
                    best_accuracy = accuracy
                    best_hyperparams = {
                        'hidden_channels': hidden_channels,
                        'learning_rate': lr,
                        'weight_decay': weight_decay
                    }
                print(f'Dataset: {dataset_name}, Hidden Channels: {hidden_channels}, Learning Rate: {lr}, Weight Decay: {weight_decay}, Accuracy: {accuracy:.4f}')

    print(f'Best Hyperparameters for {dataset_name}: {best_hyperparams}')
    print(f'Best Accuracy for {dataset_name}: {best_accuracy:.4f}')

    # Save results to DataFrame
    new_row = pd.DataFrame([{
        'Dataset': dataset_name,
        'Hidden_Channels': best_hyperparams['hidden_channels'],
        'Learning_Rate': best_hyperparams['learning_rate'],
        'Weight_Decay': best_hyperparams['weight_decay'],
        'Accuracy': best_accuracy,
        'Perturbation_Type': 'None',
        'Perturbation_Percentage': 0
    }])
    results_df = pd.concat([results_df, new_row], ignore_index=True)

    # Test perturbation strategies
    perturbation_percentages = [0.05, 0.1, 0.15, 0.2, 0.25]
    perturbation_types = ['Evenly', 'Concentrated']

    for perturbation_type in perturbation_types:
        for perturbation_percentage in perturbation_percentages:
            data = load_planetoid_data(dataset_name)
            train_idx, val_idx, test_idx = split_indices(data.num_nodes)
            data.train_mask = torch.zeros(data.num_nodes, dtype=torch.bool)
            data.val_mask = torch.zeros(data.num_nodes, dtype=torch.bool)
            data.test_mask = torch.zeros(data.num_nodes, dtype=torch.bool)
            data.train_mask[train_idx] = True
            data.val_mask[val_idx] = True
            data.test_mask[test_idx] = True

            if perturbation_type == 'Evenly':
                data = evenly_perturb_edges(data, perturbation_percentage)
            elif perturbation_type == 'Concentrated':
                data, _ = concentrated_perturb_edges(data, perturbation_percentage)

            model = GCNNet(data.num_node_features, best_hyperparams['hidden_channels'], num_classes)
            accuracy = train_model(model, data, best_hyperparams['learning_rate'], best_hyperparams['weight_decay'])
            print(f'Dataset: {dataset_name}, Perturbation: {perturbation_type}, Perturbation Percentage: {perturbation_percentage}, Accuracy: {accuracy:.4f}')

            # Save results to DataFrame
            new_row = pd.DataFrame([{
                'Dataset': dataset_name,
                'Hidden_Channels': best_hyperparams['hidden_channels'],
                'Learning_Rate': best_hyperparams['learning_rate'],
                'Weight_Decay': best_hyperparams['weight_decay'],
                'Accuracy': accuracy,
                'Perturbation_Type': perturbation_type,
                'Perturbation_Percentage': perturbation_percentage
            }])
            results_df = pd.concat([results_df, new_row], ignore_index=True)

# Save results to CSV
results_df.to_csv('gcn_results.csv', index=False)

# Plotting function
def plot_accuracies(results_df, dataset_name):
    plt.figure(figsize=(10, 6))
    for perturbation_type in results_df['Perturbation_Type'].unique():
        subset = results_df[(results_df['Dataset'] == dataset_name) & (results_df['Perturbation_Type'] == perturbation_type)]
        plt.plot(subset['Perturbation_Percentage'], subset['Accuracy'], marker='o', label=perturbation_type)
    plt.xlabel('Perturbation Percentage')
    plt.ylabel('Accuracy')
    plt.title(f'Accuracy vs Perturbation Percentage for {dataset_name}')
    plt.legend()
    plt.grid(True)
    plt.show()

# Plot accuracies for each dataset
for dataset_name in datasets:
    plot_accuracies(results_df, dataset_name)
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.1.2)
# Collecting torch_geometric
#   Downloading torch_geometric-2.5.3-py3-none-any.whl.metadata (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (2.2.1)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (3.7.5)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (4.66.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.11.4)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.9.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.2.2)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (5.9.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas) (2023.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (2024.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->torch_geometric) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->torch_geometric) (3.2.0)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Downloading torch_geometric-2.5.3-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 34.1 MB/s eta 0:00:00
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.5.3
# Processing dataset: Cora
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.cora.test.index
# Processing...
# Done!
# Statistics for Cora:
#   Number of nodes: 2708
#   Number of edges: 10556
#   Number of features: 1433
#   Number of classes: 7
#   Class distribution: [351 217 418 818 426 298 180]
# Early stopping at epoch 151
# Dataset: Cora, Hidden Channels: 16, Learning Rate: 0.1, Weight Decay: 0.0001, Accuracy: 0.8764
# Early stopping at epoch 143
# Dataset: Cora, Hidden Channels: 16, Learning Rate: 0.1, Weight Decay: 1e-05, Accuracy: 0.8819
# Early stopping at epoch 253
# Dataset: Cora, Hidden Channels: 16, Learning Rate: 0.01, Weight Decay: 0.0001, Accuracy: 0.8838
# Early stopping at epoch 250
# Dataset: Cora, Hidden Channels: 16, Learning Rate: 0.01, Weight Decay: 1e-05, Accuracy: 0.8911
# Dataset: Cora, Hidden Channels: 16, Learning Rate: 0.001, Weight Decay: 0.0001, Accuracy: 0.8579
# Early stopping at epoch 104
# Dataset: Cora, Hidden Channels: 16, Learning Rate: 0.001, Weight Decay: 1e-05, Accuracy: 0.2731
# Early stopping at epoch 138
# Dataset: Cora, Hidden Channels: 32, Learning Rate: 0.1, Weight Decay: 0.0001, Accuracy: 0.8727
# Early stopping at epoch 120
# Dataset: Cora, Hidden Channels: 32, Learning Rate: 0.1, Weight Decay: 1e-05, Accuracy: 0.8838
# Early stopping at epoch 292
# Dataset: Cora, Hidden Channels: 32, Learning Rate: 0.01, Weight Decay: 0.0001, Accuracy: 0.8838
# Early stopping at epoch 208
# Dataset: Cora, Hidden Channels: 32, Learning Rate: 0.01, Weight Decay: 1e-05, Accuracy: 0.8856
# Dataset: Cora, Hidden Channels: 32, Learning Rate: 0.001, Weight Decay: 0.0001, Accuracy: 0.8911
# Early stopping at epoch 101
# Dataset: Cora, Hidden Channels: 32, Learning Rate: 0.001, Weight Decay: 1e-05, Accuracy: 0.2731
# Early stopping at epoch 116
# Dataset: Cora, Hidden Channels: 64, Learning Rate: 0.1, Weight Decay: 0.0001, Accuracy: 0.8764
# Early stopping at epoch 112
# Dataset: Cora, Hidden Channels: 64, Learning Rate: 0.1, Weight Decay: 1e-05, Accuracy: 0.8690
# Early stopping at epoch 157
# Dataset: Cora, Hidden Channels: 64, Learning Rate: 0.01, Weight Decay: 0.0001, Accuracy: 0.8856
# Early stopping at epoch 186
# Dataset: Cora, Hidden Channels: 64, Learning Rate: 0.01, Weight Decay: 1e-05, Accuracy: 0.8819
# Dataset: Cora, Hidden Channels: 64, Learning Rate: 0.001, Weight Decay: 0.0001, Accuracy: 0.9004
# Dataset: Cora, Hidden Channels: 64, Learning Rate: 0.001, Weight Decay: 1e-05, Accuracy: 0.9022
# Early stopping at epoch 126
# Dataset: Cora, Hidden Channels: 128, Learning Rate: 0.1, Weight Decay: 0.0001, Accuracy: 0.8672
# Early stopping at epoch 126
# Dataset: Cora, Hidden Channels: 128, Learning Rate: 0.1, Weight Decay: 1e-05, Accuracy: 0.8653
# Early stopping at epoch 144
# Dataset: Cora, Hidden Channels: 128, Learning Rate: 0.01, Weight Decay: 0.0001, Accuracy: 0.8838
# Early stopping at epoch 160
# Dataset: Cora, Hidden Channels: 128, Learning Rate: 0.01, Weight Decay: 1e-05, Accuracy: 0.8856
# Early stopping at epoch 421
# Dataset: Cora, Hidden Channels: 128, Learning Rate: 0.001, Weight Decay: 0.0001, Accuracy: 0.8985
# Early stopping at epoch 436
# Dataset: Cora, Hidden Channels: 128, Learning Rate: 0.001, Weight Decay: 1e-05, Accuracy: 0.8967
# Early stopping at epoch 150
# Dataset: Cora, Hidden Channels: 256, Learning Rate: 0.1, Weight Decay: 0.0001, Accuracy: 0.8690
# Early stopping at epoch 123
# Dataset: Cora, Hidden Channels: 256, Learning Rate: 0.1, Weight Decay: 1e-05, Accuracy: 0.8690
# Early stopping at epoch 148
# Dataset: Cora, Hidden Channels: 256, Learning Rate: 0.01, Weight Decay: 0.0001, Accuracy: 0.8745
# Early stopping at epoch 149
# Dataset: Cora, Hidden Channels: 256, Learning Rate: 0.01, Weight Decay: 1e-05, Accuracy: 0.8727
# Early stopping at epoch 342
# Dataset: Cora, Hidden Channels: 256, Learning Rate: 0.001, Weight Decay: 0.0001, Accuracy: 0.8930
# Early stopping at epoch 372
# Dataset: Cora, Hidden Channels: 256, Learning Rate: 0.001, Weight Decay: 1e-05, Accuracy: 0.8911
# Early stopping at epoch 130
# Dataset: Cora, Hidden Channels: 512, Learning Rate: 0.1, Weight Decay: 0.0001, Accuracy: 0.8672
# Early stopping at epoch 129
# Dataset: Cora, Hidden Channels: 512, Learning Rate: 0.1, Weight Decay: 1e-05, Accuracy: 0.8635
# Early stopping at epoch 131
# Dataset: Cora, Hidden Channels: 512, Learning Rate: 0.01, Weight Decay: 0.0001, Accuracy: 0.8708
# Early stopping at epoch 142
# Dataset: Cora, Hidden Channels: 512, Learning Rate: 0.01, Weight Decay: 1e-05, Accuracy: 0.8708
# Early stopping at epoch 264
# Dataset: Cora, Hidden Channels: 512, Learning Rate: 0.001, Weight Decay: 0.0001, Accuracy: 0.8893
# Early stopping at epoch 297
# Dataset: Cora, Hidden Channels: 512, Learning Rate: 0.001, Weight Decay: 1e-05, Accuracy: 0.8911
# Best Hyperparameters for Cora: {'hidden_channels': 64, 'learning_rate': 0.001, 'weight_decay': 1e-05}
# Best Accuracy for Cora: 0.9022
# /tmp/ipykernel_34/717090124.py:228: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, new_row], ignore_index=True)
# Dataset: Cora, Perturbation: Evenly, Perturbation Percentage: 0.05, Accuracy: 0.8542
# Early stopping at epoch 468
# Dataset: Cora, Perturbation: Evenly, Perturbation Percentage: 0.1, Accuracy: 0.8838
# Early stopping at epoch 431
# Dataset: Cora, Perturbation: Evenly, Perturbation Percentage: 0.15, Accuracy: 0.8838
# Early stopping at epoch 480
# Dataset: Cora, Perturbation: Evenly, Perturbation Percentage: 0.2, Accuracy: 0.8911
# Early stopping at epoch 470
# Dataset: Cora, Perturbation: Evenly, Perturbation Percentage: 0.25, Accuracy: 0.8856
# Number of nodes used for perturbation: 3
# Dataset: Cora, Perturbation: Concentrated, Perturbation Percentage: 0.05, Accuracy: 0.8745
# Number of nodes used for perturbation: 8
# Dataset: Cora, Perturbation: Concentrated, Perturbation Percentage: 0.1, Accuracy: 0.8321
# Number of nodes used for perturbation: 16
# Dataset: Cora, Perturbation: Concentrated, Perturbation Percentage: 0.15, Accuracy: 0.8339
# Number of nodes used for perturbation: 29
# Dataset: Cora, Perturbation: Concentrated, Perturbation Percentage: 0.2, Accuracy: 0.7934
# Number of nodes used for perturbation: 44
# Dataset: Cora, Perturbation: Concentrated, Perturbation Percentage: 0.25, Accuracy: 0.7897
# Processing dataset: Pubmed
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.pubmed.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.pubmed.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.pubmed.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.pubmed.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.pubmed.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.pubmed.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.pubmed.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.pubmed.test.index
# Processing...
# Done!
# Statistics for Pubmed:
#   Number of nodes: 19717
#   Number of edges: 88648
#   Number of features: 500
#   Number of classes: 3
#   Class distribution: [4103 7739 7875]
# Early stopping at epoch 184
# Dataset: Pubmed, Hidden Channels: 16, Learning Rate: 0.1, Weight Decay: 0.0001, Accuracy: 0.8879
# Early stopping at epoch 312
# Dataset: Pubmed, Hidden Channels: 16, Learning Rate: 0.1, Weight Decay: 1e-05, Accuracy: 0.8849
# Dataset: Pubmed, Hidden Channels: 16, Learning Rate: 0.01, Weight Decay: 0.0001, Accuracy: 0.8760
# Early stopping at epoch 412
# Dataset: Pubmed, Hidden Channels: 16, Learning Rate: 0.01, Weight Decay: 1e-05, Accuracy: 0.8785
# Dataset: Pubmed, Hidden Channels: 16, Learning Rate: 0.001, Weight Decay: 0.0001, Accuracy: 0.8362
# Dataset: Pubmed, Hidden Channels: 16, Learning Rate: 0.001, Weight Decay: 1e-05, Accuracy: 0.8360
# Early stopping at epoch 217
# Dataset: Pubmed, Hidden Channels: 32, Learning Rate: 0.1, Weight Decay: 0.0001, Accuracy: 0.8874
# Early stopping at epoch 210
# Dataset: Pubmed, Hidden Channels: 32, Learning Rate: 0.1, Weight Decay: 1e-05, Accuracy: 0.8839
# Early stopping at epoch 318
# Dataset: Pubmed, Hidden Channels: 32, Learning Rate: 0.01, Weight Decay: 0.0001, Accuracy: 0.8785
# Early stopping at epoch 345
# Dataset: Pubmed, Hidden Channels: 32, Learning Rate: 0.01, Weight Decay: 1e-05, Accuracy: 0.8808
# Dataset: Pubmed, Hidden Channels: 32, Learning Rate: 0.001, Weight Decay: 0.0001, Accuracy: 0.8489
# Dataset: Pubmed, Hidden Channels: 32, Learning Rate: 0.001, Weight Decay: 1e-05, Accuracy: 0.8469
# Early stopping at epoch 199
# Dataset: Pubmed, Hidden Channels: 64, Learning Rate: 0.1, Weight Decay: 0.0001, Accuracy: 0.8920
# Early stopping at epoch 221
# Dataset: Pubmed, Hidden Channels: 64, Learning Rate: 0.1, Weight Decay: 1e-05, Accuracy: 0.8902
# Early stopping at epoch 248
# Dataset: Pubmed, Hidden Channels: 64, Learning Rate: 0.01, Weight Decay: 0.0001, Accuracy: 0.8796
# Early stopping at epoch 353
# Dataset: Pubmed, Hidden Channels: 64, Learning Rate: 0.01, Weight Decay: 1e-05, Accuracy: 0.8811
# Dataset: Pubmed, Hidden Channels: 64, Learning Rate: 0.001, Weight Decay: 0.0001, Accuracy: 0.8578
# Dataset: Pubmed, Hidden Channels: 64, Learning Rate: 0.001, Weight Decay: 1e-05, Accuracy: 0.8565
# Early stopping at epoch 178
# Dataset: Pubmed, Hidden Channels: 128, Learning Rate: 0.1, Weight Decay: 0.0001, Accuracy: 0.8859
# Early stopping at epoch 225
# Dataset: Pubmed, Hidden Channels: 128, Learning Rate: 0.1, Weight Decay: 1e-05, Accuracy: 0.8943
# Early stopping at epoch 225
# Dataset: Pubmed, Hidden Channels: 128, Learning Rate: 0.01, Weight Decay: 0.0001, Accuracy: 0.8808
# Early stopping at epoch 307
# Dataset: Pubmed, Hidden Channels: 128, Learning Rate: 0.01, Weight Decay: 1e-05, Accuracy: 0.8824
# Dataset: Pubmed, Hidden Channels: 128, Learning Rate: 0.001, Weight Decay: 0.0001, Accuracy: 0.8644
# Dataset: Pubmed, Hidden Channels: 128, Learning Rate: 0.001, Weight Decay: 1e-05, Accuracy: 0.8644
# Early stopping at epoch 177
# Dataset: Pubmed, Hidden Channels: 256, Learning Rate: 0.1, Weight Decay: 0.0001, Accuracy: 0.8889
# Early stopping at epoch 211
# Dataset: Pubmed, Hidden Channels: 256, Learning Rate: 0.1, Weight Decay: 1e-05, Accuracy: 0.8884
# Early stopping at epoch 178
# Dataset: Pubmed, Hidden Channels: 256, Learning Rate: 0.01, Weight Decay: 0.0001, Accuracy: 0.8798
# Early stopping at epoch 341
# Dataset: Pubmed, Hidden Channels: 256, Learning Rate: 0.01, Weight Decay: 1e-05, Accuracy: 0.8851
# Dataset: Pubmed, Hidden Channels: 256, Learning Rate: 0.001, Weight Decay: 0.0001, Accuracy: 0.8709
# Dataset: Pubmed, Hidden Channels: 256, Learning Rate: 0.001, Weight Decay: 1e-05, Accuracy: 0.8707
# Early stopping at epoch 156
# Dataset: Pubmed, Hidden Channels: 512, Learning Rate: 0.1, Weight Decay: 0.0001, Accuracy: 0.8887
# Early stopping at epoch 250
# Dataset: Pubmed, Hidden Channels: 512, Learning Rate: 0.1, Weight Decay: 1e-05, Accuracy: 0.8826
# Early stopping at epoch 382
# Dataset: Pubmed, Hidden Channels: 512, Learning Rate: 0.01, Weight Decay: 0.0001, Accuracy: 0.8844
# Early stopping at epoch 361
# Dataset: Pubmed, Hidden Channels: 512, Learning Rate: 0.01, Weight Decay: 1e-05, Accuracy: 0.8872
# Early stopping at epoch 485
# Dataset: Pubmed, Hidden Channels: 512, Learning Rate: 0.001, Weight Decay: 0.0001, Accuracy: 0.8750
# Early stopping at epoch 493
# Dataset: Pubmed, Hidden Channels: 512, Learning Rate: 0.001, Weight Decay: 1e-05, Accuracy: 0.8758
# Best Hyperparameters for Pubmed: {'hidden_channels': 128, 'learning_rate': 0.1, 'weight_decay': 1e-05}
# Best Accuracy for Pubmed: 0.8943
# Early stopping at epoch 193
# Dataset: Pubmed, Perturbation: Evenly, Perturbation Percentage: 0.05, Accuracy: 0.8920
# Early stopping at epoch 276
# Dataset: Pubmed, Perturbation: Evenly, Perturbation Percentage: 0.1, Accuracy: 0.8788
# Early stopping at epoch 224
# Dataset: Pubmed, Perturbation: Evenly, Perturbation Percentage: 0.15, Accuracy: 0.8829
# Early stopping at epoch 251
# Dataset: Pubmed, Perturbation: Evenly, Perturbation Percentage: 0.2, Accuracy: 0.8856
# Early stopping at epoch 134
# Dataset: Pubmed, Perturbation: Evenly, Perturbation Percentage: 0.25, Accuracy: 0.7764
# Number of nodes used for perturbation: 25
# Early stopping at epoch 226
# Dataset: Pubmed, Perturbation: Concentrated, Perturbation Percentage: 0.05, Accuracy: 0.8471
# Number of nodes used for perturbation: 65
# Early stopping at epoch 213
# Dataset: Pubmed, Perturbation: Concentrated, Perturbation Percentage: 0.1, Accuracy: 0.8299
# Number of nodes used for perturbation: 117
# Early stopping at epoch 191
# Dataset: Pubmed, Perturbation: Concentrated, Perturbation Percentage: 0.15, Accuracy: 0.8289
# Number of nodes used for perturbation: 179
# Early stopping at epoch 189
# Dataset: Pubmed, Perturbation: Concentrated, Perturbation Percentage: 0.2, Accuracy: 0.8063
# Number of nodes used for perturbation: 252
# Early stopping at epoch 147
# Dataset: Pubmed, Perturbation: Concentrated, Perturbation Percentage: 0.25, Accuracy: 0.8101
# Processing dataset: CiteSeer
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.x
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.tx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.allx
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.y
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.ty
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.ally
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.graph
# Downloading https://github.com/kimiyoung/planetoid/raw/master/data/ind.citeseer.test.index
# Processing...
# Done!
# Statistics for CiteSeer:
#   Number of nodes: 3327
#   Number of edges: 9104
#   Number of features: 3703
#   Number of classes: 6
#   Class distribution: [264 590 668 701 596 508]
# Early stopping at epoch 111
# Dataset: CiteSeer, Hidden Channels: 16, Learning Rate: 0.1, Weight Decay: 0.0001, Accuracy: 0.7357
# Early stopping at epoch 114
# Dataset: CiteSeer, Hidden Channels: 16, Learning Rate: 0.1, Weight Decay: 1e-05, Accuracy: 0.7297
# Early stopping at epoch 201
# Dataset: CiteSeer, Hidden Channels: 16, Learning Rate: 0.01, Weight Decay: 0.0001, Accuracy: 0.7492
# Early stopping at epoch 193
# Dataset: CiteSeer, Hidden Channels: 16, Learning Rate: 0.01, Weight Decay: 1e-05, Accuracy: 0.7583
# Early stopping at epoch 475
# Dataset: CiteSeer, Hidden Channels: 16, Learning Rate: 0.001, Weight Decay: 0.0001, Accuracy: 0.7462
# Early stopping at epoch 345
# Dataset: CiteSeer, Hidden Channels: 16, Learning Rate: 0.001, Weight Decay: 1e-05, Accuracy: 0.7387
# Early stopping at epoch 109
# Dataset: CiteSeer, Hidden Channels: 32, Learning Rate: 0.1, Weight Decay: 0.0001, Accuracy: 0.7177
# Early stopping at epoch 110
# Dataset: CiteSeer, Hidden Channels: 32, Learning Rate: 0.1, Weight Decay: 1e-05, Accuracy: 0.7252
# Early stopping at epoch 141
# Dataset: CiteSeer, Hidden Channels: 32, Learning Rate: 0.01, Weight Decay: 0.0001, Accuracy: 0.7523
# Early stopping at epoch 142
# Dataset: CiteSeer, Hidden Channels: 32, Learning Rate: 0.01, Weight Decay: 1e-05, Accuracy: 0.7492
# Early stopping at epoch 292
# Dataset: CiteSeer, Hidden Channels: 32, Learning Rate: 0.001, Weight Decay: 0.0001, Accuracy: 0.7477
# Early stopping at epoch 275
# Dataset: CiteSeer, Hidden Channels: 32, Learning Rate: 0.001, Weight Decay: 1e-05, Accuracy: 0.7523
# Early stopping at epoch 105
# Dataset: CiteSeer, Hidden Channels: 64, Learning Rate: 0.1, Weight Decay: 0.0001, Accuracy: 0.7162
# Early stopping at epoch 107
# Dataset: CiteSeer, Hidden Channels: 64, Learning Rate: 0.1, Weight Decay: 1e-05, Accuracy: 0.7147
# Early stopping at epoch 135
# Dataset: CiteSeer, Hidden Channels: 64, Learning Rate: 0.01, Weight Decay: 0.0001, Accuracy: 0.7492
# Early stopping at epoch 130
# Dataset: CiteSeer, Hidden Channels: 64, Learning Rate: 0.01, Weight Decay: 1e-05, Accuracy: 0.7508
# Early stopping at epoch 236
# Dataset: CiteSeer, Hidden Channels: 64, Learning Rate: 0.001, Weight Decay: 0.0001, Accuracy: 0.7508
# Early stopping at epoch 245
# Dataset: CiteSeer, Hidden Channels: 64, Learning Rate: 0.001, Weight Decay: 1e-05, Accuracy: 0.7568
# Early stopping at epoch 107
# Dataset: CiteSeer, Hidden Channels: 128, Learning Rate: 0.1, Weight Decay: 0.0001, Accuracy: 0.7207
# Early stopping at epoch 108
# Dataset: CiteSeer, Hidden Channels: 128, Learning Rate: 0.1, Weight Decay: 1e-05, Accuracy: 0.7117
# Early stopping at epoch 120
# Dataset: CiteSeer, Hidden Channels: 128, Learning Rate: 0.01, Weight Decay: 0.0001, Accuracy: 0.7417
# Early stopping at epoch 115
# Dataset: CiteSeer, Hidden Channels: 128, Learning Rate: 0.01, Weight Decay: 1e-05, Accuracy: 0.7477
# Early stopping at epoch 215
# Dataset: CiteSeer, Hidden Channels: 128, Learning Rate: 0.001, Weight Decay: 0.0001, Accuracy: 0.7598
# Early stopping at epoch 197
# Dataset: CiteSeer, Hidden Channels: 128, Learning Rate: 0.001, Weight Decay: 1e-05, Accuracy: 0.7613
# Early stopping at epoch 107
# Dataset: CiteSeer, Hidden Channels: 256, Learning Rate: 0.1, Weight Decay: 0.0001, Accuracy: 0.7297
# Early stopping at epoch 108
# Dataset: CiteSeer, Hidden Channels: 256, Learning Rate: 0.1, Weight Decay: 1e-05, Accuracy: 0.7147
# Early stopping at epoch 117
# Dataset: CiteSeer, Hidden Channels: 256, Learning Rate: 0.01, Weight Decay: 0.0001, Accuracy: 0.7357
# Early stopping at epoch 118
# Dataset: CiteSeer, Hidden Channels: 256, Learning Rate: 0.01, Weight Decay: 1e-05, Accuracy: 0.7357
# Early stopping at epoch 170
# Dataset: CiteSeer, Hidden Channels: 256, Learning Rate: 0.001, Weight Decay: 0.0001, Accuracy: 0.7718
# Early stopping at epoch 180
# Dataset: CiteSeer, Hidden Channels: 256, Learning Rate: 0.001, Weight Decay: 1e-05, Accuracy: 0.7733
# Early stopping at epoch 115
# Dataset: CiteSeer, Hidden Channels: 512, Learning Rate: 0.1, Weight Decay: 0.0001, Accuracy: 0.7192
# Early stopping at epoch 110
# Dataset: CiteSeer, Hidden Channels: 512, Learning Rate: 0.1, Weight Decay: 1e-05, Accuracy: 0.7222
# Early stopping at epoch 112
# Dataset: CiteSeer, Hidden Channels: 512, Learning Rate: 0.01, Weight Decay: 0.0001, Accuracy: 0.7312
# Early stopping at epoch 110
# Dataset: CiteSeer, Hidden Channels: 512, Learning Rate: 0.01, Weight Decay: 1e-05, Accuracy: 0.7342
# Early stopping at epoch 160
# Dataset: CiteSeer, Hidden Channels: 512, Learning Rate: 0.001, Weight Decay: 0.0001, Accuracy: 0.7718
# Early stopping at epoch 157
# Dataset: CiteSeer, Hidden Channels: 512, Learning Rate: 0.001, Weight Decay: 1e-05, Accuracy: 0.7763
# Best Hyperparameters for CiteSeer: {'hidden_channels': 512, 'learning_rate': 0.001, 'weight_decay': 1e-05}
# Best Accuracy for CiteSeer: 0.7763
# Early stopping at epoch 239
# Dataset: CiteSeer, Perturbation: Evenly, Perturbation Percentage: 0.05, Accuracy: 0.7538
# Early stopping at epoch 234
# Dataset: CiteSeer, Perturbation: Evenly, Perturbation Percentage: 0.1, Accuracy: 0.7372
# Early stopping at epoch 202
# Dataset: CiteSeer, Perturbation: Evenly, Perturbation Percentage: 0.15, Accuracy: 0.7598
# Early stopping at epoch 228
# Dataset: CiteSeer, Perturbation: Evenly, Perturbation Percentage: 0.2, Accuracy: 0.7583
# Early stopping at epoch 215
# Dataset: CiteSeer, Perturbation: Evenly, Perturbation Percentage: 0.25, Accuracy: 0.7823
# Number of nodes used for perturbation: 5
# Early stopping at epoch 236
# Dataset: CiteSeer, Perturbation: Concentrated, Perturbation Percentage: 0.05, Accuracy: 0.7357
# Number of nodes used for perturbation: 14
# Early stopping at epoch 214
# Dataset: CiteSeer, Perturbation: Concentrated, Perturbation Percentage: 0.1, Accuracy: 0.6952
# Number of nodes used for perturbation: 29
# Early stopping at epoch 312
# Dataset: CiteSeer, Perturbation: Concentrated, Perturbation Percentage: 0.15, Accuracy: 0.6907
# Number of nodes used for perturbation: 49
# Early stopping at epoch 273
# Dataset: CiteSeer, Perturbation: Concentrated, Perturbation Percentage: 0.2, Accuracy: 0.7207
# Number of nodes used for perturbation: 74
# Early stopping at epoch 257
# Dataset: CiteSeer, Perturbation: Concentrated, Perturbation Percentage: 0.25, Accuracy: 0.6652
